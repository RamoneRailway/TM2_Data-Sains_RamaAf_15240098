# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.7-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp312-cp312-win_amd64.whl.metadata (114 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 622.7 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/8.1 MB 622.7 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/8.1 MB 633.2 kB/s eta 0:00:12
# ...

# %%
#Nama: Rama Afriansyah
#NIM: 15240098
#Kelas: 15.3A.01

import pandas as pd

df = pd.read_csv('datatni.csv')

styled_df = df.style \
    .background_gradient(subset=['tinggi'], cmap='RdYlGn') \
    .hide(axis='index') \
    .set_properties(**{'text-align': 'left'}) \
    .set_table_styles([
        {'selector': 'th', 'props': [('text-align', 'center')]}
    ])

styled_df
# Out:
# <style type="text/css">
# #T_35461 th {
#   text-align: center;
# }
# #T_35461_row0_col0, #T_35461_row0_col1, #T_35461_row0_col3, #T_35461_row1_col0, #T_35461_row1_col1, #T_35461_row1_col3, #T_35461_row2_col0, #T_35461_row2_col1, #T_35461_row2_col3, #T_35461_row3_col0, #T_35461_row3_col1, #T_35461_row3_col3, #T_35461_row4_col0, #T_35461_row4_col1, #T_35461_row4_col3, #T_35461_row5_col0, #T_35461_row5_col1, #T_35461_row5_col3, #T_35461_row6_col0, #T_35461_row6_col1, #T_35461_row6_col3, #T_35461_row7_col0, #T_35461_row7_col1, #T_35461_row7_col3, #T_35461_row8_col0, #T_35461_row8_col1, #T_35461_row8_col3, #T_35461_row9_col0, #T_35461_row9_col1, #T_35461_row9_col3 {
#   text-align: left;
# }
# #T_35461_row0_col2 {
#   background-color: #d9ef8b;
#   color: #000000;
#   text-align: left;
# }
# #T_35461_row1_col2, #T_35461_row8_col2 {
#   background-color: #98d368;
#   color: #000000;
#   text-align: left;
# }
# #T_35461_row2_col2, #T_35461_row3_col2 {
#   background-color: #66bd63;
# ...
