# %%
#Nama: Rama Afriansyah
#NIM: 15240098
#Kelas: 15.3A.01

import pandas as pd

df = pd.read_csv('datatni.csv')

styled_df = df.style \
    .background_gradient(subset=['tinggi'], cmap='RdYlGn') \
    .hide(axis='index') \
    .set_properties(**{'text-align': 'left'}) \
    .set_table_styles([
        {'selector': 'th', 'props': [('text-align', 'center')]}
    ])

styled_df
# Out:
# <style type="text/css">
# #T_9991b th {
#   text-align: center;
# }
# #T_9991b_row0_col0, #T_9991b_row0_col1, #T_9991b_row0_col3, #T_9991b_row1_col0, #T_9991b_row1_col1, #T_9991b_row1_col3, #T_9991b_row2_col0, #T_9991b_row2_col1, #T_9991b_row2_col3, #T_9991b_row3_col0, #T_9991b_row3_col1, #T_9991b_row3_col3, #T_9991b_row4_col0, #T_9991b_row4_col1, #T_9991b_row4_col3, #T_9991b_row5_col0, #T_9991b_row5_col1, #T_9991b_row5_col3, #T_9991b_row6_col0, #T_9991b_row6_col1, #T_9991b_row6_col3, #T_9991b_row7_col0, #T_9991b_row7_col1, #T_9991b_row7_col3, #T_9991b_row8_col0, #T_9991b_row8_col1, #T_9991b_row8_col3, #T_9991b_row9_col0, #T_9991b_row9_col1, #T_9991b_row9_col3 {
#   text-align: left;
# }
# #T_9991b_row0_col2 {
#   background-color: #d9ef8b;
#   color: #000000;
#   text-align: left;
# }
# #T_9991b_row1_col2, #T_9991b_row8_col2 {
#   background-color: #98d368;
#   color: #000000;
#   text-align: left;
# }
# #T_9991b_row2_col2, #T_9991b_row3_col2 {
#   background-color: #66bd63;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_9991b_row4_col2 {
#   background-color: #148e4b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_9991b_row5_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_9991b_row6_col2 {
#   background-color: #fee08b;
#   color: #000000;
#   text-align: left;
# }
# #T_9991b_row7_col2 {
#   background-color: #fdb768;
#   color: #000000;
#   text-align: left;
# }
# #T_9991b_row9_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: left;
# }
# </style>
# <table id="T_9991b">
#   <thead>
#     <tr>
#       <th id="T_9991b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9991b_level0_col1" class="col_heading level0 col1" >alamat</th>
#       <th id="T_9991b_level0_col2" class="col_heading level0 col2" >tinggi</th>
#       <th id="T_9991b_level0_col3" class="col_heading level0 col3" >kategori</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9991b_row0_col0" class="data row0 col0" >Andi</td>
#       <td id="T_9991b_row0_col1" class="data row0 col1" >Jl. Merdeka No. 18</td>
#       <td id="T_9991b_row0_col2" class="data row0 col2" >175</td>
#       <td id="T_9991b_row0_col3" class="data row0 col3" >Sedang</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row1_col0" class="data row1 col0" >Budi</td>
#       <td id="T_9991b_row1_col1" class="data row1 col1" >Jl. Sudirman No. 5</td>
#       <td id="T_9991b_row1_col2" class="data row1 col2" >178</td>
#       <td id="T_9991b_row1_col3" class="data row1 col3" >Sedang</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row2_col0" class="data row2 col0" >Cira</td>
#       <td id="T_9991b_row2_col1" class="data row2 col1" >Jl. Thamrin No. 20</td>
#       <td id="T_9991b_row2_col2" class="data row2 col2" >180</td>
#       <td id="T_9991b_row2_col3" class="data row2 col3" >Tinggi</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row3_col0" class="data row3 col0" >Devd</td>
#       <td id="T_9991b_row3_col1" class="data row3 col1" >Jl. Gatot Subroto No. 15</td>
#       <td id="T_9991b_row3_col2" class="data row3 col2" >180</td>
#       <td id="T_9991b_row3_col3" class="data row3 col3" >Tinggi</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row4_col0" class="data row4 col0" >Eka</td>
#       <td id="T_9991b_row4_col1" class="data row4 col1" >Jl. Rasuna Said No. 8</td>
#       <td id="T_9991b_row4_col2" class="data row4 col2" >183</td>
#       <td id="T_9991b_row4_col3" class="data row4 col3" >Tinggi</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row5_col0" class="data row5 col0" >Fajar</td>
#       <td id="T_9991b_row5_col1" class="data row5 col1" >Jl. Kuningan No. 12</td>
#       <td id="T_9991b_row5_col2" class="data row5 col2" >185</td>
#       <td id="T_9991b_row5_col3" class="data row5 col3" >Tinggi</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row6_col0" class="data row6 col0" >Gina</td>
#       <td id="T_9991b_row6_col1" class="data row6 col1" >Jl. Cikini No. 3</td>
#       <td id="T_9991b_row6_col2" class="data row6 col2" >170</td>
#       <td id="T_9991b_row6_col3" class="data row6 col3" >Sedang</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row7_col0" class="data row7 col0" >Hadi</td>
#       <td id="T_9991b_row7_col1" class="data row7 col1" >Jl. Palmerah No. 7</td>
#       <td id="T_9991b_row7_col2" class="data row7 col2" >168</td>
#       <td id="T_9991b_row7_col3" class="data row7 col3" >Pendek</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row8_col0" class="data row8 col0" >Indah</td>
#       <td id="T_9991b_row8_col1" class="data row8 col1" >Jl. Senayan No. 9</td>
#       <td id="T_9991b_row8_col2" class="data row8 col2" >178</td>
#       <td id="T_9991b_row8_col3" class="data row8 col3" >Sedang</td>
#     </tr>
#     <tr>
#       <td id="T_9991b_row9_col0" class="data row9 col0" >Jilan</td>
#       <td id="T_9991b_row9_col1" class="data row9 col1" >Jl. Kuningan No. 2</td>
#       <td id="T_9991b_row9_col2" class="data row9 col2" >160</td>
#       <td id="T_9991b_row9_col3" class="data row9 col3" >Pendek</td>
#     </tr>
#   </tbody>
# </table>
